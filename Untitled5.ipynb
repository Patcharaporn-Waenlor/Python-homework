# %%
class Parant:
    def __init__(self):
        pass

    def hello(self):
        print("หวัดดี")

# %%
class Child(Parant):
    def __init__(self):
        pass

    def hello(self):
        print("สวัสดีค่ะ")

# %%
person = Child()
person.hello()
# Out:
# สวัสดีค่ะ
